# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("Survey Dataset - Technical Interview.csv")

# %%
data.head(3)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
# 2            3       5-24-2017       Rural   Graduate   ₹ 5,000 - ₹ 10,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction age gender  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied  26   Male
# 1     RLSP     JD(U)  Somewhat Satisfied  Fully Dissatisfied  34   Male
# 2   JAP(L)       BJP  Fully Dissatisfied  Somewhat Satisfied  25   Male
#
#    assembly_no category    weight
# 0          211      Gen  0.346969
# 1          189       BC  0.603419
# 2          191      Gen  0.673762

# %%
data.dtypes
# Out:
# response_id           int64
# collection_date      object
# urban_rural          object
# education            object
# income               object
# Vote_Now             object
# Past_Vote            object
# CM_satisfaction      object
# MLA_satisfaction     object
# age                  object
# gender               object
# assembly_no           int64
# category             object
# weight              float64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6867 entries, 0 to 6866
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   response_id       6867 non-null   int64
#  1   collection_date   6867 non-null   object
#  2   urban_rural       6867 non-null   object
#  3   education         6867 non-null   object
#  4   income            6867 non-null   object
#  5   Vote_Now          6867 non-null   object
#  6   Past_Vote         6867 non-null   object
#  7   CM_satisfaction   6867 non-null   object
#  8   MLA_satisfaction  6867 non-null   object
#  9   age               6867 non-null   object
#  10  gender            6867 non-null   object
#  11  assembly_no       6867 non-null   int64
#  12  category          6867 non-null   object
#  13  weight            6867 non-null   float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 751.2+ KB

# %%
data.isnull().sum()
# Out:
# response_id         0
# collection_date     0
# urban_rural         0
# education           0
# income              0
# Vote_Now            0
# Past_Vote           0
# CM_satisfaction     0
# MLA_satisfaction    0
# age                 0
# gender              0
# assembly_no         0
# category            0
# weight              0
# dtype: int64

# %%
data.columns
# Out:
# Index(['response_id', 'collection_date', 'urban_rural', 'education', 'income',
#        'Vote_Now', 'Past_Vote', 'CM_satisfaction', 'MLA_satisfaction', 'age',
#        'gender', 'assembly_no', 'category', 'weight'],
#       dtype='object')

# %%
data.shape
# Out:
# (6867, 14)

# %%
#show all the unique value of columns
data['CM_satisfaction'].unique()
# Out:
# array(['Fully Dissatisfied', 'Somewhat Satisfied', 'Fully Satisfied',
#        'Somewhat Dissatisfied', 'Can’t say'], dtype=object)

# %%
#show total number of unique value
data['CM_satisfaction'].nunique()
# Out:
# 5

# %%
# show all value of a column with their count
data['CM_satisfaction'].value_counts()
# Out:
# Fully Dissatisfied       3012
# Somewhat Satisfied       2218
# Fully Satisfied           721
# Somewhat Dissatisfied     680
# Can’t say                 236
# Name: CM_satisfaction, dtype: int64

# %% [markdown]
# ##  what proportion of the total respondents were aged less then 45 ?

# %%
data.head(2)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction age gender  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied  26   Male
# 1     RLSP     JD(U)  Somewhat Satisfied  Fully Dissatisfied  34   Male
#
#    assembly_no category    weight
# 0          211      Gen  0.346969
# 1          189       BC  0.603419

# %%
data['age']<45
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7952/1424085269.py in <module>
# ----> 1 data['age']<45
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# ~\anaconda3\lib\site-packages\pandas\core\arraylike.py in __lt__(self, other)
#      38     @unpack_zerodim_and_defer("__lt__")
#      39     def __lt__(self, other):
# ---> 40         return self._cmp_method(other, operator.lt)
#      41
#      42     @unpack_zerodim_and_defer("__le__")
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _cmp_method(self, other, op)
#    5500
#    5501         with np.errstate(all="ignore"):
# -> 5502             res_values = ops.comparison_op(lvalues, rvalues, op)
# ...

# %%
data.age.dtype
# Out:
# dtype('O')

# %%
data.age.unique()
# Out:
# array(['26', '34', '25', '36', '22', '38', '23', '42', '51', '29', '24',
#        '30', '39', '37', '19', '44', '53', '32', '21', '18', '20', '27',
#        '48', '28', '45', '74', '35', '31', '70', '40', '49', '46', '43',
#        '41', '33', '58', '24ko', '56', '50', '55', '54', '62', '60', '59',
#        '47', '61', '52', '66', '57', '67', '65', '71', '63', '64', '68',
#        '69', '99', '72', '75', '76'], dtype=object)

# %%
# to show all unique value of a column with their count
data.age.value_counts()
# Out:
# 25      598
# 24      449
# 30      440
# 28      396
# 22      392
# 26      389
# 27      360
# 20      328
# 23      317
# 21      311
# 32      263
# 35      263
# 29      239
# 40      177
# 34      173
# 19      171
# 31      159
# 33      143
# 38      135
# 36      127
# 18      125
# 42      104
# 37       90
# 45       82
# 43       72
# 39       69
# 50       60
# 41       54
# 44       54
# 48       35
# 47       34
# 46       32
# 49       27
# 52       24
# 51       23
# 55       20
# 60       15
# 53       12
# 61       12
# 54       11
# 57       10
# 56        9
# 58        9
# 64        8
# 67        7
# 62        5
# 59        5
# 65        5
# 68        4
# 63        4
# 66        4
# 70        3
# 71        2
# 74        1
# 24ko      1
# 69        1
# 99        1
# 72        1
# 75        1
# 76        1
# Name: age, dtype: int64

# %%
data['age']=data['age'].replace({'24ko':24})

# %%
data.age.unique()
# Out:
# array(['26', '34', '25', '36', '22', '38', '23', '42', '51', '29', '24',
#        '30', '39', '37', '19', '44', '53', '32', '21', '18', '20', '27',
#        '48', '28', '45', '74', '35', '31', '70', '40', '49', '46', '43',
#        '41', '33', '58', 24, '56', '50', '55', '54', '62', '60', '59',
#        '47', '61', '52', '66', '57', '67', '65', '71', '63', '64', '68',
#        '69', '99', '72', '75', '76'], dtype=object)

# %%
data.age.value_counts()
# Out:
# 25    598
# 24    449
# 30    440
# 28    396
# 22    392
# 26    389
# 27    360
# 20    328
# 23    317
# 21    311
# 32    263
# 35    263
# 29    239
# 40    177
# 34    173
# 19    171
# 31    159
# 33    143
# 38    135
# 36    127
# 18    125
# 42    104
# 37     90
# 45     82
# 43     72
# 39     69
# 50     60
# 41     54
# 44     54
# 48     35
# 47     34
# 46     32
# 49     27
# 52     24
# 51     23
# 55     20
# 60     15
# 53     12
# 61     12
# 54     11
# 57     10
# 56      9
# 58      9
# 64      8
# 67      7
# 62      5
# 59      5
# 65      5
# 68      4
# 63      4
# 66      4
# 70      3
# 71      2
# 74      1
# 24      1
# 69      1
# 99      1
# 72      1
# 75      1
# 76      1
# Name: age, dtype: int64

# %%
data['age']=data.age.astype(int)

# %%
data.dtypes
# Out:
# response_id           int64
# collection_date      object
# urban_rural          object
# education            object
# income               object
# Vote_Now             object
# Past_Vote            object
# CM_satisfaction      object
# MLA_satisfaction     object
# age                   int32
# gender               object
# assembly_no           int64
# category             object
# weight              float64
# dtype: object

# %%
data[data['age']<45]
# Out:
#       response_id collection_date urban_rural               education  \
# 0               1       5-24-2017       Rural               12th Pass
# 1               2       5-24-2017       Rural                Graduate
# 2               3       5-24-2017       Rural                Graduate
# 3               4       5-24-2017       Urban                Graduate
# 4               5       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6862         6863        6-1-2017       Rural               10th Pass
# 6863         6864        6-1-2017       Rural                Graduate
# 6864         6865        6-1-2017       Urban                Graduate
# 6865         6866        6-1-2017       Rural  Professional Education
# 6866         6867        6-1-2017       Rural               10th Pass
#
#                    income Vote_Now     Past_Vote     CM_satisfaction  \
# ...

# %%
6399/6867*100
# Out:
# 93.18479685452162

# %% [markdown]
# ### create a new column in the dataframe 'age group' . this column should contain the age group the respondant belong to. the age groups are 18-25, 25-40, 40-55 and 55+ . the dataframe should look like this after the column creation :

# %%
survey=data.copy()            #to make a copy of dataframe

# %%
survey.head(2)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction  age gender  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied   26   Male
# 1     RLSP     JD(U)  Somewhat Satisfied  Fully Dissatisfied   34   Male
#
#    assembly_no category    weight
# 0          211      Gen  0.346969
# 1          189       BC  0.603419

# %%
# df_name.insert('new column position','new column name','new column values') 

survey.insert(10, 'age group', survey.age)

# %%
survey.head(2)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction  age  age group  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied   26         26
# 1     RLSP     JD(U)  Somewhat Satisfied  Fully Dissatisfied   34         34
#
#   gender  assembly_no category    weight
# 0   Male          211      Gen  0.346969
# 1   Male          189       BC  0.603419

# %%
data1=survey[(survey['age group']>=18)&(survey['age group']<25)]

# %%
data1.head(5)
# Out:
#     response_id collection_date urban_rural          education  \
# 4             5       5-24-2017       Rural           Graduate
# 8             9       5-24-2017       Urban          12th Pass
# 14           15       5-24-2017       Rural           Graduate
# 16           17       5-24-2017       Rural  Post - Graduation
# 18           19       5-24-2017       Rural           Graduate
#
#                  income Vote_Now     Past_Vote        CM_satisfaction  \
# 4   ₹ 50,000 - ₹ 80,000    JD(U)  Did not vote        Fully Satisfied
# 8     BPL/Below ₹ 5,000      BJP           BJP        Fully Satisfied
# 14   ₹ 1,50,000 & above      BJP           BJP        Fully Satisfied
# 16    BPL/Below ₹ 5,000      RJD           RJD     Fully Dissatisfied
# 18  ₹ 30,000 - ₹ 50,000   JAP(L)         JD(U)  Somewhat Dissatisfied
#
#       MLA_satisfaction  age  age group gender  assembly_no category    weight
# 4      Fully Satisfied   22         22   Male          176       BC  0.333505
# ...

# %%
data1['age group'].unique()
# Out:
# array([22, 23, 24, 19, 21, 18, 20])

# %%
data1['age group']='18-25'
# Out:
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_7952/4212060430.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['age group']='18-25'

# %%
data1.loc['age group']='18-25'

# %%
data1.head(2)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 4            5       5-24-2017       Rural   Graduate  ₹ 50,000 - ₹ 80,000
# 8            9       5-24-2017       Urban  12th Pass    BPL/Below ₹ 5,000
#
#   Vote_Now     Past_Vote  CM_satisfaction    MLA_satisfaction  age age group  \
# 4    JD(U)  Did not vote  Fully Satisfied     Fully Satisfied   22     18-25
# 8      BJP           BJP  Fully Satisfied  Fully Dissatisfied   23     18-25
#
#   gender  assembly_no category    weight
# 4   Male          176       BC  0.333505
# 8   Male          181      Gen  0.226477

# %%
data2 = survey[(survey['age group']>=25)&(survey['age group']<40)]

# %%
data2.loc['age group']='25-40'

# %%
data3=survey[(survey['age group']>=40)&(survey['age group']<55)]

# %%
 data3.loc['age group']='40-55'

# %%
 data4=survey[(survey['age group']>=55)]

# %%
data4.loc['age group']='55+'

# %%
survey=pd.concat([data1,data2,data3,data4])

# %%
survey['age group'].unique()
# Out:
# array(['18-25', '25-40', '40-55', '55+'], dtype=object)

# %%
survey.tail(3)
# Out:
#           response_id collection_date urban_rural  education  \
# 6787             6788        6-1-2017       Rural  10th Pass
# 6851             6852        6-1-2017       Urban   Graduate
# age group         55+             55+         55+        55+
#
#                         income Vote_Now Past_Vote  CM_satisfaction  \
# 6787       ₹ 20,000 - ₹ 30,000    JD(U)       BJP  Fully Satisfied
# 6851       ₹ 30,000 - ₹ 50,000      BJP       BJP  Fully Satisfied
# age group                  55+      55+       55+              55+
#
#                 MLA_satisfaction  age age group gender assembly_no category  \
# 6787             Fully Satisfied   60       55+   Male         144       SC
# 6851       Somewhat Dissatisfied   66       55+   Male         165      Gen
# age group                    55+  55+       55+    55+         55+      55+
#
#              weight
# 6787       4.741094
# 6851        0.30099
# age group       55+

# %% [markdown]
# ### 5. how many samples were collected for each group ? which age-group had the most samples?

# %%
survey['age group'].value_counts()
# Out:
# 25-40    3845
# 18-25    2095
# 40-55     129
# 55+       129
# Name: age group, dtype: int64

# %% [markdown]
# ### 6.what proportion of the respondents had opted  for the RJD party in both the vote_now and the past_vote question

# %%
data.head(2)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction  age  age group  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied   26         26
# 1     RLSP     JD(U)  Somewhat Satisfied  Fully Dissatisfied   34         34
#
#   gender  assembly_no category    weight
# 0   Male          211      Gen  0.346969
# 1   Male          189       BC  0.603419

# %%
survey[(survey['Past_Vote']=='RJD')&(survey['Vote_Now']=='RJD')]
# Out:
#      response_id collection_date urban_rural          education  \
# 16            17       5-24-2017       Rural  Post - Graduation
# 38            39       5-24-2017       Urban           Graduate
# 47            48       5-24-2017       Urban           Graduate
# 85            86       5-24-2017       Rural          12th Pass
# 120          121       5-24-2017       Rural           Graduate
# ...          ...             ...         ...                ...
# 4753        4754       5-26-2017       Rural  Post - Graduation
# 5493        5494       5-26-2017       Urban           Graduate
# 5687        5688       5-29-2017       Urban           Graduate
# 5830        5831       5-30-2017       Urban           Graduate
# 6151        6152       5-24-2017       Rural           Graduate
#
#                    income Vote_Now Past_Vote        CM_satisfaction  \
# 16      BPL/Below ₹ 5,000      RJD       RJD     Fully Dissatisfied
# ...

# %%
762/6867*100
# Out:
# 11.09654871122761

# %% [markdown]
# ### for each day of sample collection, determine the proportion of repondents who were fully satisfied with the performance of the C.M . so if there were a total of  1000 samples on day 1 and 300 out of those said they were fully satisfied, then our answer for that day would be 0.3

# %%
survey.head(2)
# Out:
#   response_id collection_date urban_rural  education               income  \
# 4           5       5-24-2017       Rural   Graduate  ₹ 50,000 - ₹ 80,000
# 8           9       5-24-2017       Urban  12th Pass    BPL/Below ₹ 5,000
#
#   Vote_Now     Past_Vote  CM_satisfaction    MLA_satisfaction age age group  \
# 4    JD(U)  Did not vote  Fully Satisfied     Fully Satisfied  22     18-25
# 8      BJP           BJP  Fully Satisfied  Fully Dissatisfied  23     18-25
#
#   gender assembly_no category    weight
# 4   Male         176       BC  0.333505
# 8   Male         181      Gen  0.226477

# %%
survey['CM_satisfaction'].unique()
# Out:
# array(['Fully Satisfied', 'Fully Dissatisfied', 'Somewhat Dissatisfied',
#        'Can’t say', 'Somewhat Satisfied', '18-25', '25-40', '40-55',
#        '55+'], dtype=object)

# %%
CM.head(2)
# Out:
#    response_id collection_date urban_rural          education  \
# 16          17       5-24-2017       Rural  Post - Graduation
# 24          25       5-24-2017       Rural          12th Pass
#
#                  income Vote_Now Past_Vote     CM_satisfaction  \
# 16    BPL/Below ₹ 5,000      RJD       RJD  Fully Dissatisfied
# 24  ₹ 50,000 - ₹ 80,000   Others       BJP  Fully Dissatisfied
#
#       MLA_satisfaction age age group gender assembly_no category    weight
# 16  Somewhat Satisfied  24     18-25   Male         194       BC  0.769738
# 24           Can’t say  19     18-25   Male         193      Gen  0.247091

# %%
CM['CM_satisfaction'].value_counts()
# Out:
# Fully Satisfied    662
# Name: CM_satisfaction, dtype: int64

# %%
CM = survey[survey['CM_satisfaction']=='Fully Satisfied']

# %%
a=CM.collection_date.value_counts()

# %%
b= survey.collection_date.value_counts()

# %%
c=a/b*100
print(c)
# Out:
# 18-25              NaN
# 25-40              NaN
# 40-55              NaN
# 5-24-2017     9.794989
# 5-25-2017     8.849558
# 5-26-2017     9.461967
# 5-27-2017     7.966102
# 5-28-2017    13.544669
# 5-29-2017    13.105925
# 5-30-2017    11.216730
# 5-31-2017    11.198428
# 55+                NaN
# 6-1-2017     12.903226
# Name: collection_date, dtype: float64

# %% [markdown]
# ### 8.in a similar fashion create a day-wise proportion of respondants that opted fully dissatified with their MLA. Create a line plot of the result with data on x-axis and proportions on the y-axis.

# %%
data.head(2)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction  age  age group  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied   26         26
# 1     RLSP     JD(U)  Somewhat Satisfied  Fully Dissatisfied   34         34
#
#   gender  assembly_no category    weight
# 0   Male          211      Gen  0.346969
# 1   Male          189       BC  0.603419

# %%
survey[survey['MLA_satisfaction']=='Fully Dissatisfied'].head(2)
# Out:
#    response_id collection_date urban_rural  education              income  \
# 8            9       5-24-2017       Urban  12th Pass   BPL/Below ₹ 5,000
# 14          15       5-24-2017       Rural   Graduate  ₹ 1,50,000 & above
#
#    Vote_Now Past_Vote  CM_satisfaction    MLA_satisfaction age age group  \
# 8       BJP       BJP  Fully Satisfied  Fully Dissatisfied  23     18-25
# 14      BJP       BJP  Fully Satisfied  Fully Dissatisfied  24     18-25
#
#    gender assembly_no category    weight
# 8    Male         181      Gen  0.226477
# 14   Male         199      Gen  0.226477

# %%
mla=survey[survey['MLA_satisfaction']=='Fully Dissatisfied']

# %%
x=mla.collection_date.value_counts()
x
# Out:
# 5-24-2017    797
# 5-25-2017    566
# 5-28-2017    410
# 6-1-2017     356
# 5-27-2017    355
# 5-30-2017    327
# 5-26-2017    324
# 5-29-2017    314
# 5-31-2017    297
# Name: collection_date, dtype: int64

# %%
y=survey.collection_date.value_counts()
y
# Out:
# 5-24-2017    1317
# 5-25-2017     904
# 5-28-2017     694
# 5-27-2017     590
# 6-1-2017      558
# 5-29-2017     557
# 5-26-2017     539
# 5-30-2017     526
# 5-31-2017     509
# 18-25           1
# 25-40           1
# 40-55           1
# 55+             1
# Name: collection_date, dtype: int64

# %%
z=x/y*100
print(z)
# Out:
# 18-25              NaN
# 25-40              NaN
# 40-55              NaN
# 5-24-2017    60.516325
# 5-25-2017    62.610619
# 5-26-2017    60.111317
# 5-27-2017    60.169492
# 5-28-2017    59.077810
# 5-29-2017    56.373429
# 5-30-2017    62.167300
# 5-31-2017    58.349705
# 55+                NaN
# 6-1-2017     63.799283
# Name: collection_date, dtype: float64

# %%
type(z)
# Out:
# pandas.core.series.Series

# %%
z1=pd.DataFrame(z)

# %%
z1
# Out:
#            collection_date
# 18-25                  NaN
# 25-40                  NaN
# 40-55                  NaN
# 5-24-2017        60.516325
# 5-25-2017        62.610619
# 5-26-2017        60.111317
# 5-27-2017        60.169492
# 5-28-2017        59.077810
# 5-29-2017        56.373429
# 5-30-2017        62.167300
# 5-31-2017        58.349705
# 55+                    NaN
# 6-1-2017         63.799283

# %%
z1.collection_date.plot(kind='line')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 9. create a pivot-table(or crosstab) with index as past_vote , column as vote_now and cell values as the count of samples.

# %%
survey.head(2)
# Out:
#   response_id collection_date urban_rural  education               income  \
# 4           5       5-24-2017       Rural   Graduate  ₹ 50,000 - ₹ 80,000
# 8           9       5-24-2017       Urban  12th Pass    BPL/Below ₹ 5,000
#
#   Vote_Now     Past_Vote  CM_satisfaction    MLA_satisfaction age age group  \
# 4    JD(U)  Did not vote  Fully Satisfied     Fully Satisfied  22     18-25
# 8      BJP           BJP  Fully Satisfied  Fully Dissatisfied  23     18-25
#
#   gender assembly_no category    weight
# 4   Male         176       BC  0.333505
# 8   Male         181      Gen  0.226477

# %%
data.pivot_table(index = 'Past_Vote',columns ='Vote_Now', aggfunc='count')
# Out:
#              CM_satisfaction                                              \
# Vote_Now                 AAP AIMIM     BJP  BSP  HAM   INC JAP(L)  JD(U)
# Past_Vote
# BJP                      7.0   1.0  1630.0  3.0  5.0  42.0  101.0  110.0
# BSP                      NaN   1.0     2.0  5.0  NaN   1.0    NaN    NaN
# Did not vote             8.0   5.0   231.0  2.0  1.0  22.0   41.0   69.0
# HAM                      2.0   NaN    25.0  NaN  1.0   NaN    3.0    2.0
# INC                      NaN   6.0     6.0  NaN  NaN  57.0   10.0    9.0
# JAP(L)                   NaN   NaN     4.0  NaN  NaN   NaN   35.0    NaN
# JD(U)                    6.0  10.0   254.0  2.0  2.0  45.0   72.0  279.0
# LJP                      NaN   NaN    76.0  1.0  NaN   4.0    3.0    6.0
# Left Front               NaN   1.0     2.0  NaN  NaN   1.0    NaN    NaN
# NOTA                     NaN   1.0    29.0  1.0  NaN   9.0    7.0    7.0
# Others                   1.0   5.0    45.0  1.0  1.0   4.0    7.0    4.0
# ...

# %% [markdown]
# ### repeat the above question with the cell values as the sum of 'weight'

# %%
data.pivot_table(index = 'Past_Vote',columns ='Vote_Now', values='weight', aggfunc='sum')
# Out:
# Vote_Now            AAP      AIMIM          BJP        BSP        HAM  \
# Past_Vote
# BJP            4.807335   0.349996  1049.344112   0.452551  10.171283
# BSP                 NaN   1.654731     5.174487  32.010277        NaN
# Did not vote   8.865896   5.379527   114.203906   3.329611   2.497170
# HAM            0.312607        NaN    25.348884        NaN   1.648856
# INC                 NaN  11.105958     1.642875        NaN        NaN
# JAP(L)              NaN        NaN     6.512846        NaN        NaN
# JD(U)         12.457216  29.198610   156.243100  11.005903   2.639574
# LJP                 NaN        NaN    85.010450   2.481377        NaN
# Left Front          NaN   2.298223     0.209586        NaN        NaN
# NOTA                NaN   1.061204    12.685435   0.051485        NaN
# Others        13.661335  21.212705    34.866218   0.684568   1.505864
# RJD            5.515847  24.149369    32.285093        NaN   0.960400
# ...

# %% [markdown]
# ### create a dataframe by performing a group by over age group and calculate the count of total samples under each age group

# %%
df1= survey.groupby('age group').count()

# %%
df1
# Out:
#            response_id  collection_date  urban_rural  education  income  \
# age group
# 18-25             2095             2095         2095       2095    2095
# 25-40             3845             3845         3845       3845    3845
# 40-55              129              129          129        129     129
# 55+                129              129          129        129     129
#
#            Vote_Now  Past_Vote  CM_satisfaction  MLA_satisfaction   age  \
# age group
# 18-25          2095       2095             2095              2095  2095
# 25-40          3845       3845             3845              3845  3845
# 40-55           129        129              129               129   129
# 55+             129        129              129               129   129
#
#            gender  assembly_no  category  weight
# age group
# 18-25        2095         2095      2095    2095
# 25-40        3845         3845      3845    3845
# 40-55         129          129       129     129
# ...

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### 12.  create a dataframe by performing a group by over group age and finding the count of total samples for each age group that opted for the JDU party  in vote_now

# %%
data.head(2)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction  age  age group  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied   26         26
# 1     RLSP     JD(U)  Somewhat Satisfied  Fully Dissatisfied   34         34
#
#   gender  assembly_no category    weight
# 0   Male          211      Gen  0.346969
# 1   Male          189       BC  0.603419

# %%
survey['Past_Vote'].unique()
# Out:
# array(['Did not vote', 'BJP', 'RJD', 'JD(U)', 'VIP', 'NOTA', 'Others',
#        'INC', 'LJP', 'HAM', 'BSP', 'Left Front', 'JAP(L)', 'RLSP',
#        '18-25', '25-40', '40-55', '55+'], dtype=object)

# %%
survey[survey['Vote_Now']=='JD(U)'].head(2)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 4            5       5-24-2017       Rural   Graduate  ₹ 50,000 - ₹ 80,000
# 67          68       5-24-2017       Urban  12th Pass   ₹ 5,000 - ₹ 10,000
#
#    Vote_Now     Past_Vote     CM_satisfaction    MLA_satisfaction age  \
# 4     JD(U)  Did not vote     Fully Satisfied     Fully Satisfied  22
# 67    JD(U)  Did not vote  Somewhat Satisfied  Fully Dissatisfied  24
#
#    age group gender assembly_no category    weight
# 4      18-25   Male         176       BC  0.333505
# 67     18-25   Male         184       SC  2.427588

# %%
jdu=survey[survey['Vote_Now']=='JD(U)']

# %%
jdu.groupby('age group').count().head()
# Out:
#            response_id  collection_date  urban_rural  education  income  \
# age group
# 18-25              181              181          181        181     181
# 25-40              264              264          264        264     264
# 40-55               13               13           13         13      13
# 55+                 13               13           13         13      13
#
#            Vote_Now  Past_Vote  CM_satisfaction  MLA_satisfaction  age  \
# age group
# 18-25           181        181              181               181  181
# 25-40           264        264              264               264  264
# 40-55            13         13               13                13   13
# 55+              13         13               13                13   13
#
#            gender  assembly_no  category  weight
# age group
# 18-25         181          181       181     181
# 25-40         264          264       264     264
# 40-55          13           13        13      13
# ...

# %%
df2=jdu.groupby('age group').count()

# %% [markdown]
# ### 13. join /merge the two dataframes from questions 12 and 11 with the common column as age group

# %%
df1
# Out:
#            response_id  collection_date  urban_rural  education  income  \
# age group
# 18-25             2095             2095         2095       2095    2095
# 25-40             3845             3845         3845       3845    3845
# 40-55              129              129          129        129     129
# 55+                129              129          129        129     129
#
#            Vote_Now  Past_Vote  CM_satisfaction  MLA_satisfaction   age  \
# age group
# 18-25          2095       2095             2095              2095  2095
# 25-40          3845       3845             3845              3845  3845
# 40-55           129        129              129               129   129
# 55+             129        129              129               129   129
#
#            gender  assembly_no  category  weight
# age group
# 18-25        2095         2095      2095    2095
# 25-40        3845         3845      3845    3845
# 40-55         129          129       129     129
# ...

# %%
df2
# Out:
#            response_id  collection_date  urban_rural  education  income  \
# age group
# 18-25              181              181          181        181     181
# 25-40              264              264          264        264     264
# 40-55               13               13           13         13      13
# 55+                 13               13           13         13      13
#
#            Vote_Now  Past_Vote  CM_satisfaction  MLA_satisfaction  age  \
# age group
# 18-25           181        181              181               181  181
# 25-40           264        264              264               264  264
# 40-55            13         13               13                13   13
# 55+              13         13               13                13   13
#
#            gender  assembly_no  category  weight
# age group
# 18-25         181          181       181     181
# 25-40         264          264       264     264
# 40-55          13           13        13      13
# ...

# %%
pd.merge(df1,df2, on='age group')
# Out:
#            response_id_x  collection_date_x  urban_rural_x  education_x  \
# age group
# 18-25               2095               2095           2095         2095
# 25-40               3845               3845           3845         3845
# 40-55                129                129            129          129
# 55+                  129                129            129          129
#
#            income_x  Vote_Now_x  Past_Vote_x  CM_satisfaction_x  \
# age group
# 18-25          2095        2095         2095               2095
# 25-40          3845        3845         3845               3845
# 40-55           129         129          129                129
# 55+             129         129          129                129
#
#            MLA_satisfaction_x  age_x  ...  income_y  Vote_Now_y  Past_Vote_y  \
# age group                             ...
# 18-25                    2095   2095  ...       181         181          181
# ...
